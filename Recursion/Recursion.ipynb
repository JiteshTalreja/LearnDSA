# %% [markdown]
# ## RECURSION STACK WORKS

# %%
def func_one():
    print(1)
    func_two()

def func_two():
    print(2)
    func_three()

def func_three():
    print(3)

# %%
def func_one():
    func_two()
    print(1)

def func_two():
    func_three()
    print(2)

def func_three():
    print(3)

# %%
def func_one():
    print(1)

def func_two():
    func_one()
    print(2)

def func_three():
    func_two()
    print(3)

func_three()
# Out:
# 1
# 2
# 3
